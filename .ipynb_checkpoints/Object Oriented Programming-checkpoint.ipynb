# %%
#Example 1:
class Phone:
    def make_call(self):
        print('Making a phone call')
    def play_game(self):
        print('Playing game')

# %%
p1 = Phone()
p1.make_call()
# Out:
# Making a phone call

# %%
p1.play_game()
# Out:
# Playing game

# %%
#Example 2:
class Phone:
    def set_color(self, color):
        self.color = color
    def set_cost(self, cost):
        self.cost = cost
    def show_color(self):
        return self.color
    def show_cost(self):
        return self.cost
    def make_call(self):
        print('Making a call')
    def play_game(self):
        print('Playing game')

# %%
p2 = Phone()

# %%
p2.make_call()
# Out:
# Making a call

# %%
p2.set_color('White')
p2.set_cost(500)

# %%
p2.show_cost()
# Out:
# 500

# %%
p2.show_color()
# Out:
# 'White'

# %%
#Example 3:
class Employee:
    def __init__(self,name, age, salary, gender):
        self.name = name
        self.age = age
        self.salary = salary
        self.gender = gender
        
    def employee_details(self):
        print('Name of employee is', self.name)
        print('Age of employee is', self.age)
        print('Salary of employee is', self.salary)
        print('Gender of employee is', self.gender)

# %%
e1 = Employee('Aman',26,100000,'M')

# %%
e1.employee_details()
# Out:
# Name of employee is Aman
# Age of employee is 26
# Salary of employee is 100000
# Gender of employee is M

# %%
#Example 4: Inheritence,
class Vehicle:
    def __init__(self, milage, cost, hp):
        self.milage = milage
        self.cost = cost
        self.hp = hp
        
    def Vehicle_details(self):
        print('Milage of the Vehicle is', self.milage)
        print('Cost of the Vehicle is', self.cost)
        print('Horse power of the Vehicle is', self.hp)

# %%
v1 = Vehicle(50,10000,746)

# %%
v1.Vehicle_details()
# Out:
# Milage of the Vehicle is 50
# Cost of the Vehicle is 10000
# Horse power of the Vehicle is 746

# %%
v1.cost
# Out:
# 10000

# %%
v1.hp
# Out:
# 746

# %%
v1.milage
# Out:
# 50

# %%
class Car(Vehicle):
    def car_details(self):
        print("I'm a Car")

# %%
c1 = Car(30,2000,1000)

# %%
c1.car_details()
# Out:
# I'm a Car

# %%
c1.Vehicle_details()
# Out:
# Milage of the Vehicle is 30
# Cost of the Vehicle is 2000
# Horse power of the Vehicle is 1000

# %%
#Example 5: Inheritence,
class Vehicle:
    def __init__(self, milage, cost, hp):
        self.milage = milage
        self.cost = cost
        self.hp = hp
        
    def Vehicle_details(self):
        print('Milage of the Vehicle is', self.milage)
        print('Cost of the Vehicle is', self.cost)
        print('Horse power of the Vehicle is', self.hp)

# %%
class Car(Vehicle):
    def __init__(self, milage, cost, hp, tyre):
        super().__init__(milage, cost, hp),
        self.tyre = tyre
        
    def car_details(self):
        print("I'm a Car")

# %%
c2 = Car(30,300000,300,8)

# %%
c2.car_details()
# Out:
# I'm a Car

# %%
c2.Vehicle_details()
# Out:
# Milage of the Vehicle is 30
# Cost of the Vehicle is 300000
# Horse power of the Vehicle is 300

# %%
#Example 6: Mutltiple inheritence
class Parent1:
    def assing_name1(self,str1):
        self.str1 = str1
    def show_name1(self):
        print('The name is',str1)

# %%
class Parent2:
    def assing_name2(self,str2):
        self.str2 = str2
    def show_name2(self):
        print('The name is',str2)

# %%
class Parent(Parent1,Parent2):
    def assing_name3(self,str3):
        self.str3 = str3
    def show_name3(self):
        print('The name is',str3)

# %%
p1 = Parent()

# %%
p1.assing_name1('Aman')

# %%
p1.assing_name2('David')

# %% [markdown]
# ![Screenshot%202022-02-15%20at%203.32.38%20PM.png](attachment:Screenshot%202022-02-15%20at%203.32.38%20PM.png)

# %% [markdown]
# #Example 6
# ![Screenshot%202022-02-15%20at%203.31.47%20PM.png](attachment:Screenshot%202022-02-15%20at%203.31.47%20PM.png)

# %%
class Parent():
    def assign_name(self, name):
        self.name = name
    def show_name(self):
        return self.name

# %%
class Child(Parent):
    def assign_age(self, age):
        self.age = age
    def show_age(self):
        return self.age

# %%
class Grandchild(Child):
    def assign_gender(self, gender):
        self.gender = gender
    def show_gender(self):
        return self.gender

# %%
a = Grandchild()

# %%
a.assign_age(21)
a.show_age()
# Out:
# 21
